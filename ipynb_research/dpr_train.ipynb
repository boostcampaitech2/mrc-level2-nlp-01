# %%
# !pip install grpcio-tools==1.34.1
# !pip install git+https://github.com/deepset-ai/haystack.git
# Out:
# Requirement already satisfied: grpcio-tools==1.34.1 in ./venv/lib/python3.8/site-packages (1.34.1)
# Requirement already satisfied: protobuf<4.0dev,>=3.5.0.post1 in ./venv/lib/python3.8/site-packages (from grpcio-tools==1.34.1) (3.19.1)
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from grpcio-tools==1.34.1) (58.3.0)
# Requirement already satisfied: grpcio>=1.34.1 in ./venv/lib/python3.8/site-packages (from grpcio-tools==1.34.1) (1.37.1)
# Requirement already satisfied: six>=1.5.2 in ./venv/lib/python3.8/site-packages (from grpcio>=1.34.1->grpcio-tools==1.34.1) (1.16.0)
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-lkh3cjr3
#   Running command git clone --filter=blob:none -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-lkh3cjr3
#   Resolved https://github.com/deepset-ai/haystack.git to commit da90acf650da08a5c5f48b79e418b39c6ae0a0ec
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (58.3.0)
# Requirement already satisfied: wheel in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.37.0)
# Requirement already satisfied: torch<1.10,>1.5 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.9.1)
# Requirement already satisfied: tqdm in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (4.62.3)
# Requirement already satisfied: requests in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.26.0)
# Requirement already satisfied: scipy>=1.3.2 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.7.1)
# Requirement already satisfied: sklearn in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.0)
# Requirement already satisfied: seqeval in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.2.2)
# Requirement already satisfied: mlflow<=1.13.1 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.13.1)
# Requirement already satisfied: transformers==4.7.0 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (4.7.0)
# Requirement already satisfied: dill in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.3.4)
# Requirement already satisfied: psutil in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (5.8.0)
# Requirement already satisfied: fastapi in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.70.0)
# Requirement already satisfied: uvicorn in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.15.0)
# Requirement already satisfied: gunicorn in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (20.1.0)
# Requirement already satisfied: pandas in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.3.4)
# Requirement already satisfied: elasticsearch<=7.10,>=7.7 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (7.10.0)
# Requirement already satisfied: elastic-apm in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (6.6.0)
# Requirement already satisfied: tox in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (3.24.4)
# Requirement already satisfied: coverage in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (6.1)
# Requirement already satisfied: langdetect in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.0.9)
# Requirement already satisfied: pytesseract==0.3.7 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.3.7)
# Requirement already satisfied: pillow==8.3.2 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (8.3.2)
# Requirement already satisfied: pdf2image==1.14.0 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.14.0)
# Requirement already satisfied: sentence-transformers>=0.4.0 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.1.0)
# Requirement already satisfied: python-multipart in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.0.5)
# Requirement already satisfied: python-docx in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.8.11)
# Requirement already satisfied: sqlalchemy>=1.4.2 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.4.26)
# Requirement already satisfied: sqlalchemy_utils in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.37.9)
# Requirement already satisfied: faiss-cpu>=1.6.3 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.7.1.post2)
# Requirement already satisfied: tika in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.24)
# Requirement already satisfied: httptools in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.3.0)
# Requirement already satisfied: nltk in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (3.6.5)
# Requirement already satisfied: more_itertools in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (8.10.0)
# Requirement already satisfied: networkx in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.6.3)
# Requirement already satisfied: pymilvus in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.1.2)
# Requirement already satisfied: SPARQLWrapper in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.8.5)
# Requirement already satisfied: mmh3 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (3.0.0)
# Requirement already satisfied: weaviate-client==2.5.0 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.5.0)
# Requirement already satisfied: ray==1.5.0 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (1.5.0)
# Requirement already satisfied: dataclasses-json in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.5.6)
# Requirement already satisfied: quantulum3 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.7.9)
# Requirement already satisfied: psycopg2-binary in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (2.9.1)
# Requirement already satisfied: uvloop==0.14 in ./venv/lib/python3.8/site-packages (from farm-haystack==1.0.0rc1) (0.14.0)
# Requirement already satisfied: redis>=3.5.0 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.5.3)
# Requirement already satisfied: prometheus-client>=0.7.1 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.12.0)
# Requirement already satisfied: py-spy>=0.2.0 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.3.10)
# Requirement already satisfied: colorama in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.4.4)
# Requirement already satisfied: pydantic>=1.8 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.8.2)
# Requirement already satisfied: click>=7.0 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (8.0.3)
# Requirement already satisfied: aiohttp in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.7.4.post0)
# Requirement already satisfied: pyyaml in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (6.0)
# Requirement already satisfied: jsonschema in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (4.1.2)
# Requirement already satisfied: filelock in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.3.2)
# Requirement already satisfied: opencensus in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.8.0)
# Requirement already satisfied: numpy>=1.16 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.21.3)
# Requirement already satisfied: gpustat in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.6.0)
# Requirement already satisfied: aiohttp-cors in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (0.7.0)
# Requirement already satisfied: protobuf>=3.15.3 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (3.19.1)
# Requirement already satisfied: grpcio>=1.28.1 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.37.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (1.0.2)
# Requirement already satisfied: aioredis in ./venv/lib/python3.8/site-packages (from ray==1.5.0->farm-haystack==1.0.0rc1) (2.0.0)
# Requirement already satisfied: packaging in ./venv/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (21.2)
# Requirement already satisfied: huggingface-hub==0.0.8 in ./venv/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (0.0.8)
# Requirement already satisfied: regex!=2019.12.17 in ./venv/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (2021.10.23)
# Requirement already satisfied: sacremoses in ./venv/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (0.0.46)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in ./venv/lib/python3.8/site-packages (from transformers==4.7.0->farm-haystack==1.0.0rc1) (0.10.3)
# Requirement already satisfied: validators>=0.18.2 in ./venv/lib/python3.8/site-packages (from weaviate-client==2.5.0->farm-haystack==1.0.0rc1) (0.18.2)
# Requirement already satisfied: urllib3<2,>=1.21.1 in ./venv/lib/python3.8/site-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.0.0rc1) (1.26.7)
# Requirement already satisfied: certifi in ./venv/lib/python3.8/site-packages (from elasticsearch<=7.10,>=7.7->farm-haystack==1.0.0rc1) (2021.10.8)
# Requirement already satisfied: alembic<=1.4.1 in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.4.1)
# Requirement already satisfied: docker>=4.0.0 in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (5.0.3)
# Requirement already satisfied: azure-storage-blob>=12.0.0 in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (12.9.0)
# Requirement already satisfied: querystring-parser in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.2.4)
# Requirement already satisfied: entrypoints in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.3)
# Requirement already satisfied: sqlparse>=0.3.1 in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.4.2)
# Requirement already satisfied: python-dateutil in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.8.2)
# Requirement already satisfied: gitpython>=2.1.0 in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.1.24)
# Requirement already satisfied: databricks-cli>=0.8.7 in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.16.2)
# Requirement already satisfied: prometheus-flask-exporter in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.18.4)
# Requirement already satisfied: Flask in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.0.2)
# Requirement already satisfied: cloudpickle in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.0.0)
# Requirement already satisfied: six>=1.10.0 in ./venv/lib/python3.8/site-packages (from mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.8/site-packages (from requests->farm-haystack==1.0.0rc1) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in ./venv/lib/python3.8/site-packages (from requests->farm-haystack==1.0.0rc1) (2.0.7)
# Requirement already satisfied: torchvision in ./venv/lib/python3.8/site-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (0.11.1)
# Requirement already satisfied: scikit-learn in ./venv/lib/python3.8/site-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (1.0.1)
# Requirement already satisfied: sentencepiece in ./venv/lib/python3.8/site-packages (from sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (0.1.96)
# Requirement already satisfied: greenlet!=0.4.17 in ./venv/lib/python3.8/site-packages (from sqlalchemy>=1.4.2->farm-haystack==1.0.0rc1) (1.1.2)
# Requirement already satisfied: typing-extensions in ./venv/lib/python3.8/site-packages (from torch<1.10,>1.5->farm-haystack==1.0.0rc1) (3.10.0.2)
# Requirement already satisfied: typing-inspect>=0.4.0 in ./venv/lib/python3.8/site-packages (from dataclasses-json->farm-haystack==1.0.0rc1) (0.7.1)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in ./venv/lib/python3.8/site-packages (from dataclasses-json->farm-haystack==1.0.0rc1) (1.5.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in ./venv/lib/python3.8/site-packages (from dataclasses-json->farm-haystack==1.0.0rc1) (3.14.0)
# Requirement already satisfied: starlette==0.16.0 in ./venv/lib/python3.8/site-packages (from fastapi->farm-haystack==1.0.0rc1) (0.16.0)
# Requirement already satisfied: anyio<4,>=3.0.0 in ./venv/lib/python3.8/site-packages (from starlette==0.16.0->fastapi->farm-haystack==1.0.0rc1) (3.3.4)
# Requirement already satisfied: joblib in ./venv/lib/python3.8/site-packages (from nltk->farm-haystack==1.0.0rc1) (1.1.0)
# Requirement already satisfied: pytz>=2017.3 in ./venv/lib/python3.8/site-packages (from pandas->farm-haystack==1.0.0rc1) (2021.3)
# Requirement already satisfied: ujson>=2.0.0 in ./venv/lib/python3.8/site-packages (from pymilvus->farm-haystack==1.0.0rc1) (4.2.0)
# Requirement already satisfied: grpcio-tools<1.38.0,>=1.22.0 in ./venv/lib/python3.8/site-packages (from pymilvus->farm-haystack==1.0.0rc1) (1.34.1)
# Requirement already satisfied: lxml>=2.3.2 in ./venv/lib/python3.8/site-packages (from python-docx->farm-haystack==1.0.0rc1) (4.6.3)
# Requirement already satisfied: inflect in ./venv/lib/python3.8/site-packages (from quantulum3->farm-haystack==1.0.0rc1) (5.3.0)
# Requirement already satisfied: num2words in ./venv/lib/python3.8/site-packages (from quantulum3->farm-haystack==1.0.0rc1) (0.5.10)
# Requirement already satisfied: rdflib>=4.0 in ./venv/lib/python3.8/site-packages (from SPARQLWrapper->farm-haystack==1.0.0rc1) (6.0.2)
# Requirement already satisfied: py>=1.4.17 in ./venv/lib/python3.8/site-packages (from tox->farm-haystack==1.0.0rc1) (1.10.0)
# Requirement already satisfied: virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0 in ./venv/lib/python3.8/site-packages (from tox->farm-haystack==1.0.0rc1) (20.9.0)
# Requirement already satisfied: toml>=0.9.4 in ./venv/lib/python3.8/site-packages (from tox->farm-haystack==1.0.0rc1) (0.10.2)
# Requirement already satisfied: pluggy>=0.12.0 in ./venv/lib/python3.8/site-packages (from tox->farm-haystack==1.0.0rc1) (1.0.0)
# Requirement already satisfied: h11>=0.8 in ./venv/lib/python3.8/site-packages (from uvicorn->farm-haystack==1.0.0rc1) (0.12.0)
# Requirement already satisfied: asgiref>=3.4.0 in ./venv/lib/python3.8/site-packages (from uvicorn->farm-haystack==1.0.0rc1) (3.4.1)
# Requirement already satisfied: Mako in ./venv/lib/python3.8/site-packages (from alembic<=1.4.1->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.1.5)
# Requirement already satisfied: python-editor>=0.3 in ./venv/lib/python3.8/site-packages (from alembic<=1.4.1->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.0.4)
# Requirement already satisfied: msrest>=0.6.21 in ./venv/lib/python3.8/site-packages (from azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.6.21)
# Requirement already satisfied: cryptography>=2.1.4 in ./venv/lib/python3.8/site-packages (from azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (35.0.0)
# Requirement already satisfied: azure-core<2.0.0,>=1.10.0 in ./venv/lib/python3.8/site-packages (from azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.19.0)
# Requirement already satisfied: tabulate>=0.7.7 in ./venv/lib/python3.8/site-packages (from databricks-cli>=0.8.7->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (0.8.9)
# Requirement already satisfied: websocket-client>=0.32.0 in ./venv/lib/python3.8/site-packages (from docker>=4.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.2.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in ./venv/lib/python3.8/site-packages (from gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (4.0.9)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in ./venv/lib/python3.8/site-packages (from packaging->transformers==4.7.0->farm-haystack==1.0.0rc1) (2.4.7)
# Requirement already satisfied: isodate in ./venv/lib/python3.8/site-packages (from rdflib>=4.0->SPARQLWrapper->farm-haystack==1.0.0rc1) (0.6.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in ./venv/lib/python3.8/site-packages (from scikit-learn->sentence-transformers>=0.4.0->farm-haystack==1.0.0rc1) (3.0.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in ./venv/lib/python3.8/site-packages (from typing-inspect>=0.4.0->dataclasses-json->farm-haystack==1.0.0rc1) (0.4.3)
# Requirement already satisfied: decorator>=3.4.0 in ./venv/lib/python3.8/site-packages (from validators>=0.18.2->weaviate-client==2.5.0->farm-haystack==1.0.0rc1) (5.1.0)
# Requirement already satisfied: platformdirs<3,>=2 in ./venv/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack==1.0.0rc1) (2.4.0)
# Requirement already satisfied: backports.entry-points-selectable>=1.0.4 in ./venv/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack==1.0.0rc1) (1.1.0)
# Requirement already satisfied: distlib<1,>=0.3.1 in ./venv/lib/python3.8/site-packages (from virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0->tox->farm-haystack==1.0.0rc1) (0.3.3)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (5.2.0)
# Requirement already satisfied: attrs>=17.3.0 in ./venv/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (21.2.0)
# Requirement already satisfied: chardet<5.0,>=2.0 in ./venv/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (4.0.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (1.7.0)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in ./venv/lib/python3.8/site-packages (from aiohttp->ray==1.5.0->farm-haystack==1.0.0rc1) (3.0.1)
# Requirement already satisfied: Jinja2>=3.0 in ./venv/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.0.2)
# Requirement already satisfied: itsdangerous>=2.0 in ./venv/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.0.1)
# Requirement already satisfied: Werkzeug>=2.0 in ./venv/lib/python3.8/site-packages (from Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.0.2)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in ./venv/lib/python3.8/site-packages (from gpustat->ray==1.5.0->farm-haystack==1.0.0rc1) (7.352.0)
# Requirement already satisfied: blessings>=1.6 in ./venv/lib/python3.8/site-packages (from gpustat->ray==1.5.0->farm-haystack==1.0.0rc1) (1.7)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in ./venv/lib/python3.8/site-packages (from jsonschema->ray==1.5.0->farm-haystack==1.0.0rc1) (0.18.0)
# Requirement already satisfied: docopt>=0.6.2 in ./venv/lib/python3.8/site-packages (from num2words->quantulum3->farm-haystack==1.0.0rc1) (0.6.2)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in ./venv/lib/python3.8/site-packages (from opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (2.2.1)
# Requirement already satisfied: opencensus-context==0.1.2 in ./venv/lib/python3.8/site-packages (from opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.1.2)
# Collecting torchvision
#   Using cached torchvision-0.10.1-cp38-cp38-manylinux1_x86_64.whl (22.1 MB)
# Requirement already satisfied: sniffio>=1.1 in ./venv/lib/python3.8/site-packages (from anyio<4,>=3.0.0->starlette==0.16.0->fastapi->farm-haystack==1.0.0rc1) (1.2.0)
# Requirement already satisfied: cffi>=1.12 in ./venv/lib/python3.8/site-packages (from cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.15.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in ./venv/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython>=2.1.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (5.0.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in ./venv/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (1.53.0)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in ./venv/lib/python3.8/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (2.3.2)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.8/site-packages (from Jinja2>=3.0->Flask->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.0.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in ./venv/lib/python3.8/site-packages (from msrest>=0.6.21->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (1.3.0)
# Requirement already satisfied: pycparser in ./venv/lib/python3.8/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (2.20)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in ./venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in ./venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in ./venv/lib/python3.8/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (4.7.2)
# Requirement already satisfied: oauthlib>=3.0.0 in ./venv/lib/python3.8/site-packages (from requests-oauthlib>=0.5.0->msrest>=0.6.21->azure-storage-blob>=12.0.0->mlflow<=1.13.1->farm-haystack==1.0.0rc1) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in ./venv/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray==1.5.0->farm-haystack==1.0.0rc1) (0.4.8)
# Installing collected packages: torchvision
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.11.1
#     Uninstalling torchvision-0.11.1:
#       Successfully uninstalled torchvision-0.11.1
# Successfully installed torchvision-0.10.1

# %%
from haystack.nodes import DensePassageRetriever
from haystack.document_stores import InMemoryDocumentStore
# Out:
# /opt/ml/code/ipynb_research/venv/lib/python3.8/site-packages/ray/autoscaler/_private/cli_logger.py:57: FutureWarning: Not all Ray CLI dependencies were found. In Ray 1.4+, the Ray CLI, autoscaler, and dashboard will only be usable via `pip install 'ray[default]'`. Please update your install command.
#   warnings.warn(

# %%
query_model = "klue/roberta-small"
passage_model = "klue/roberta-small"

# %%
retriever = DensePassageRetriever(
    document_store=InMemoryDocumentStore(),
    query_embedding_model=query_model,
    passage_embedding_model=passage_model,
    max_seq_len_query=64,
    max_seq_len_passage=256
)
# Out:
# Using a model of type 'roberta' which might be incompatible with DPR encoders.Bert based encoders are supported that need input_ids,token_type_ids,attention_mask as input tensors.
# Some weights of the model checkpoint at klue/roberta-small were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-small and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Using a model of type 'roberta' which might be incompatible with DPR encoders.Bert based encoders are supported that need input_ids,token_type_ids,attention_mask as input tensors.
# Some weights of the model checkpoint at klue/roberta-small were not used when initializing RobertaModel: ['lm_head.bias', 'lm_head.decoder.weight', 'lm_head.dense.weight', 'lm_head.layer_norm.weight', 'lm_head.dense.bias', 'lm_head.layer_norm.bias', 'lm_head.decoder.bias']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-small and are newly initialized: ['roberta.pooler.dense.weight', 'roberta.pooler.dense.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Failed to log params: Changing param values is not allowed. Param with key='lm1_name' was already logged with value='klue/bert-base' for run ID='3b0364fd099342e4b651639640251efe'. Attempted logging new value 'klue/roberta-small'.

# %%
retriever.train(
    data_dir='./',
    train_filename='train.json',
    dev_filename='valid.json',
    test_filename='valid.json',
    n_epochs=1,
    batch_size=8,
    grad_acc_steps=8,
    save_dir='./save',
    evaluate_every=3000,
    embed_title=True,
    num_positives=1,
    num_hard_negatives=1
)
# Out:
# Preprocessing Dataset train.json: 100%|██████████| 3952/3952 [00:10<00:00, 378.55 Dicts/s]
# Preprocessing Dataset valid.json: 100%|██████████| 240/240 [00:01<00:00, 169.59 Dicts/s]
# Preprocessing Dataset valid.json: 100%|██████████| 240/240 [00:01<00:00, 179.51 Dicts/s]
# Train epoch 0/0 (Cur. train loss: 20.9336): 100%|██████████| 494/494 [06:28<00:00,  1.27it/s]
# Evaluating: 100%|██████████| 30/30 [00:07<00:00,  4.19it/s]
