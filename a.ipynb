# %%
import json

with open("../data/tag_docs.json", "r", encoding='UTF-8') as json_data:
  wiki_data = json.load(json_data)
wiki_data['0']
# Out:
# {'komoran': [['이', 'MM'],
#   ['문서', 'NNP'],
#   ['는', 'JX'],
#   ['나라 목록', 'NNP'],
#   ['이', 'VCP'],
#   ['며', 'EC'],
#   [',', 'SP'],
#   ['전', 'MM'],
#   ['세계', 'NNG'],
#   ['206', 'SN'],
#   ['개', 'NNB'],
#   ['나라', 'NNG'],
#   ['의', 'JKG'],
#   ['각', 'MM'],
#   ['현황', 'NNG'],
#   ['과', 'JC'],
#   ['주권', 'NNP'],
#   ['승인', 'NNP'],
#   ['정보', 'NNG'],
#   ['를', 'JKO'],
#   ['개요', 'NNP'],
#   ['형태', 'NNG'],
#   ['로', 'JKB'],
#   ['나열', 'NNG'],
#   ['하', 'XSV'],
#   ['고', 'EC'],
#   ['있', 'VX'],
#   ['다', 'EF'],
#   ['.', 'SF'],
#   ['이', 'MM'],
#   ['목록', 'NNG'],
#   ['은', 'JX'],
#   ['명료', 'XR'],
#   ['화', 'XSN'],
#   ['를', 'JKO'],
#   ['위하', 'VV'],
#   ['아', 'EC'],
#   ['두', 'MM'],
#   ['부분', 'NNG'],
#   ['으로', 'JKB'],
#   ['나뉘', 'VV'],
#   ['어', 'EC'],
#   ['있', 'VX'],
#   ['다', 'EF'],
#   ['.', 'SF'],
#   ['첫', 'MM'],
#   ['번', 'NNB'],
#   ['째', 'XSN'],
#   ['부분', 'NNG'],
#   ['은', 'JX'],
#   ['바티칸 시국', 'NNP'],
#   ['과', 'JC'],
#   ['팔레스타인', 'NNP'],
#   ['을', 'JKO'],
# ...

# %%
wiki_data['1'].keys()
# Out:
# dict_keys(['komoran', 'okt', 'mecab'])

# %%
wiki_data['4557']['okt']
# Out:
# [['아오', 'Exclamation'],
#  ['조르다', 'Verb'],
#  ['문고', 'Noun'],
#  ['(', 'Punctuation'],
#  [',', 'Punctuation'],
#  ['아오', 'Exclamation'],
#  ['조르다', 'Verb'],
#  ['분고', 'Noun'],
#  [')', 'Punctuation'],
#  ['늘다', 'Verb'],
#  ['일본어', 'Noun'],
#  ['판', 'Noun'],
#  ['구텐베르크', 'Noun'],
#  ['프로젝트', 'Noun'],
#  ['로', 'Noun'],
#  ['불리다', 'Verb'],
#  ['일본', 'Noun'],
#  ['의', 'Josa'],
#  ['인터넷', 'Noun'],
#  ['전자', 'Noun'],
#  ['도서관', 'Noun'],
#  ['으로', 'Josa'],
#  [',', 'Punctuation'],
#  ['저작권', 'Noun'],
#  ['이', 'Josa'],
#  ['풀리다', 'Verb'],
#  ['문학작품', 'Noun'],
#  ['을', 'Josa'],
#  ['수집', 'Noun'],
#  [',', 'Punctuation'],
#  ['전자문서', 'Noun'],
#  ['화하다', 'Adjective'],
#  ['인터넷', 'Noun'],
#  ['에', 'Josa'],
#  ['공개', 'Noun'],
#  ['하고', 'Josa'],
#  ['있다', 'Adjective'],
#  ['.', 'Punctuation'],
#  ['저자', 'Noun'],
#  ['사후', 'Noun'],
#  ['50년', 'Number'],
#  ['이', 'Foreign'],
#  ['지난', 'Noun'],
#  ['메이지', 'Noun'],
#  [',', 'Punctuation'],
#  ['쇼', 'Noun'],
#  ['와', 'Josa'],
#  ['시대', 'Noun'],
# ...
