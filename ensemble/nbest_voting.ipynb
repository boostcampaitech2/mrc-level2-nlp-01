# %%
# 설정해야 할것
probability = 0.6

# %%
import json

# %%
with open("nbest_predictions.json", "r") as f:
  nbest_predictions = json.load(f)

# %%
key = nbest_predictions.keys()

# %%
answer_dict = {}

# %%
for key in nbest_predictions.keys():
  answer_dict[key.split('_')[0]] = []

# %%
for key in nbest_predictions.keys():
  id_key = key.split('_')[0]
  answer_dict[id_key].append([nbest_predictions[key][0]['text'], 0.45 * nbest_predictions[key][0]['doc_score'] + 0.55 * nbest_predictions[key][0]['probability']])

# %%
new_answer_dict = {}
for key in answer_dict.keys():
  answer_dict[key].sort(key=lambda x: x[1], reversed=True)
  new_answer_dict[key] = answer_dict[key][0][0]

# %%
with open('nbest_voting_predictions.json', "w", encoding="utf-8") as writer:
  writer.write(json.dumps(new_answer_dict, indent=4, ensure_ascii=False) + "\n")
# Out:
# {'mrc-1-000653': '달',
#  'mrc-1-001113': '냉전',
#  'mrc-0-002191': '대통령인 빌헬름 미클라스',
#  'mrc-0-003951': '뉴질랜드',
#  'mrc-1-001272': '베트남',
#  'mrc-1-000993': '유두',
#  'mrc-0-005021': '91년 체제',
#  'mrc-1-000163': '용암',
#  'mrc-0-001283': '1811)',
#  'mrc-0-004543': '고전도성 철',
#  'mrc-0-000439': '리처드 말킨',
#  'mrc-0-002895': '칼라치',
#  'mrc-0-000535': '롭 포드',
#  'mrc-1-001724': '노스햄프턴 교회',
#  'mrc-0-000901': '세실리',
#  'mrc-0-001606': '석조 궁륭',
#  'mrc-0-000266': '국민',
#  'mrc-0-001326': "'자유'지에",
#  'mrc-0-000032': '북한',
#  'mrc-0-005215': '영산사',
#  'mrc-0-005407': '숙의 정씨',
#  'mrc-0-003683': '국가인권위원회',
#  'mrc-0-003644': '이탈리아',
#  'mrc-0-002835': '망자',
#  'mrc-0-000049': '',
#  'mrc-1-001829': '화흡',
#  'mrc-1-001662': '보신 전쟁',
#  'mrc-0-001206': '2007년',
#  'mrc-0-004007': '신시내티대학교',
#  'mrc-1-000418': '암벽',
#  'mrc-0-003133': '쥘',
#  'mrc-0-004646': '건늠선',
#  'mrc-0-001058': '기원정사',
#  'mrc-0-002361': '독립',
#  'mrc-0-004830': '13개',
#  'mrc-0-002762': '황산',
#  'mrc-0-000395': '후쿠도메 시게루',
#  'mrc-0-001668': '미시시피주 머니 시에 거주하는 삼촌과 사촌 형제들을 방문하기 위해 기차를 탔다. 그의 어머니',
#  'mrc-0-004487': '조지. H. 버제스',
#  'mrc-0-001086': '라이프치히',
#  'mrc-0-004413': '호어벨리샤',
#  'mrc-1-000221': '목제',
#  'mrc-0-002177': '시트로엥',
#  'mrc-0-003223': '폴 베나세라프',
#  'mrc-0-000624': '노르웨이',
#  'mrc-0-004318': '1943년 7월 2일',
#  'mrc-0-002764': '카에데 소이치로(소리마치 타카시)',
#  'mrc-0-001725': '스털링 실리펀트',
#  'mrc-0-004445': '2019년 8월 1일',
#  'mrc-0-000001': "'강연옥",
#  'mrc-0-005411': '사비나',
#  'mrc-1-001280': '미국 대통령 우드로 윌슨',
#  'mrc-0-003385': '1584년(선조 17년)',
#  'mrc-1-001555': '나가시마',
#  'mrc-0-000854': '1971년',
#  'mrc-0-000504': '삼국시대',
#  'mrc-0-000988': '',
#  'mrc-0-003763': '조성 원문',
#  'mrc-1-001619': '쿠니키다(国木田独歩)',
#  'mrc-0-004880': '스테이플턴',
#  'mrc-0-003177': '"연금"',
#  'mrc-1-001523': '니 기븐',
#  'mrc-1-001353': '애굽',
#  'mrc-0-005278': '근세',
#  'mrc-0-003896': '송정',
#  'mrc-0-000339': '시칠리아',
#  'mrc-0-001183': '러더퍼드 B. 헤이스',
#  'mrc-1-001155': '광고',
#  'mrc-0-000991': '윌리엄 3세',
#  'mrc-0-005328': '고려 초기',
#  'mrc-0-002070': '압력',
#  'mrc-0-003298': '요아힘 뢰프',
#  'mrc-0-002453': '요미우리',
#  'mrc-0-003274': '학계',
#  'mrc-0-004430': '하인',
#  'mrc-0-003455': '스포츠 신문',
#  'mrc-0-003628': '판권관리',
#  'mrc-0-000432': '조선건국동맹',
#  'mrc-0-000540': '',
#  'mrc-0-000607': '비정상적으로 큰 송곳니',
#  'mrc-0-003540': '마리아나 해전',
#  'mrc-1-001466': '1938년',
#  'mrc-0-004954': '제5중대장 김상흥 대위',
#  'mrc-0-004159': '해 (지지)(지지)단계',
#  'mrc-0-001235': '화석',
#  'mrc-1-000813': '마리아나 제도에서 벗어나자',
#  'mrc-0-002445': '콘라트 2세',
#  'mrc-0-004336': '예루살렘 성전',
#  'mrc-0-001346': '전한 고제',
#  'mrc-0-003364': '아우구스투스 시대',
#  'mrc-0-001891': '학업에 집중하기 위해',
#  'mrc-0-000033': '하난야',
#  'mrc-0-000201': '블라인드 테스트',
#  'mrc-0-003670': '에드나 파커',
#  'mrc-0-002224': '군대 내 성소수자 권리 정책',
#  'mrc-0-000140': '오코 카무',
#  'mrc-0-001124': '구수정',
#  'mrc-0-003870': '6개',
#  'mrc-0-000386': '야즈데게르드 3세',
#  'mrc-0-005260': '안드레아스',
#  'mrc-0-004345': '1981년',
#  'mrc-1-000376': '시나위 대금',
#  'mrc-0-001470': '경기도 광명',
#  'mrc-1-000715': '네스토리우스',
#  'mrc-0-002747': '믈라크',
#  'mrc-1-001341': '가상 연좌시위',
#  'mrc-0-003597': '기원전 11년',
#  'mrc-0-003509': '미국 긴축정책',
#  'mrc-0-001335': '노예를 해방',
#  'mrc-0-004402': '1995년',
#  'mrc-1-001239': '차량 외부 스피커',
#  'mrc-1-000225': '1802년',
#  'mrc-0-003315': '보안',
#  'mrc-0-004971': '천도교 대종사장(大宗司長)',
#  'mrc-0-004538': '밀',
#  'mrc-0-001940': '신라 경문왕 3년(863)',
#  'mrc-1-000573': '큰곰자리 운동성군',
#  'mrc-0-005403': '1720년',
#  'mrc-0-002046': '모겐소',
#  'mrc-0-001943': '디지털 영상',
#  'mrc-1-001141': '《후한서》',
#  'mrc-0-002709': '남자의 시체',
#  'mrc-0-000313': '케빈 G. 린치',
#  'mrc-0-003110': '난씨',
#  'mrc-0-003155': '스카만드로스 강',
#  'mrc-1-001242': '볼바라',
#  'mrc-0-004432': '연합국',
#  'mrc-0-000755': '이태웅',
#  'mrc-1-001802': '호메이니',
#  'mrc-0-001241': '환율 부문',
#  'mrc-1-001457': '도요토미 히데요시',
#  'mrc-0-000016': '',
#  'mrc-1-000695': '고려 말',
#  'mrc-1-000908': '구충제 및 변비',
#  'mrc-0-001034': '형 선고의 효력',
#  'mrc-1-001735': '마리아 팔코네티',
#  'mrc-1-001179': '쿠페',
#  'mrc-1-000521': '종 맨 위',
#  'mrc-1-000623': '',
#  'mrc-0-003953': '평균비용',
#  'mrc-0-002008': 'HA1 도메인의 18번 코돈',
#  'mrc-0-001699': '미터법',
#  'mrc-0-002374': '무로마치 막부',
#  'mrc-1-000086': '이승만',
#  'mrc-0-004490': '벽감 알파벳 배열',
#  'mrc-1-000780': '강 노인',
#  'mrc-0-000037': '미켈란젤로',
#  'mrc-0-003187': '기암절벽',
#  'mrc-1-000021': '국가안보',
#  'mrc-1-001634': '《나무 그림》',
#  'mrc-1-000116': '토마스',
#  'mrc-0-004669': "'그리스도의 대리자'",
#  'mrc-0-002210': '이상사',
#  'mrc-0-004266': '미국',
#  'mrc-1-000862': '대막리지 연개소문',
#  'mrc-0-001884': '하반신',
#  'mrc-0-003249': '노르웨이',
#  'mrc-0-001728': '잉글랜드',
#  'mrc-0-000986': '마라도나',
#  'mrc-0-000970': '고천제',
#  'mrc-0-004182': '파시즘',
#  'mrc-0-003970': '센리 선',
#  'mrc-0-004626': '웅기탁',
#  'mrc-0-000065': '1,668만 5천 달러',
#  'mrc-0-003016': '신춘문예공모전',
#  'mrc-0-000304': '1919년 10월 1일',
#  'mrc-0-003205': '조선후기',
#  'mrc-0-002169': '다케다 한시(武田範之)',
#  'mrc-0-002771': '보이저',
#  'mrc-0-003359': '고속 이동하는 장난감',
#  'mrc-1-000666': '여름철',
#  'mrc-0-003123': '세르비아군',
#  'mrc-0-003614': '간',
#  'mrc-1-000791': '금융위원회',
#  'mrc-1-001485': '에베소',
#  'mrc-1-001025': '「티탄즈」',
#  'mrc-0-003425': '3차',
#  'mrc-0-002676': '아루에',
#  'mrc-0-001432': '1887년',
#  'mrc-1-001332': '',
#  'mrc-0-001281': '사법부',
#  'mrc-0-003224': '91 cm 구경의 굴절망원경',
#  'mrc-0-000496': '5월 8일',
#  'mrc-0-001384': '미술과',
#  'mrc-0-003067': '대통령',
#  'mrc-0-004545': '3대로',
#  'mrc-0-004460': '경영난',
#  'mrc-0-002975': '라슈트라쿠타',
#  'mrc-0-004389': '구경꾼',
#  'mrc-0-005180': 'Lea et al (1987)',
#  'mrc-0-001374': '1309년',
#  'mrc-0-000431': '자기장',
#  'mrc-0-001783': '자자 빙크스',
#  'mrc-0-000359': '영국',
#  'mrc-0-002967': '이라크',
#  'mrc-0-001838': '2010년',
#  'mrc-0-000021': '1862년',
#  'mrc-0-004709': '블랙홀',
#  'mrc-0-003085': '80~90%',
#  'mrc-0-005332': '백제금동대향로',
#  'mrc-1-001594': '자유송환',
#  'mrc-1-000856': 'CN',
#  'mrc-0-003629': '유성생식',
#  'mrc-0-005210': '마르크 오버르마르스',
#  'mrc-0-002685': '1876년',
#  'mrc-0-002938': '율스루트',
#  'mrc-0-002936': '붉은 군대',
#  'mrc-0-002389': '유교문화',
#  'mrc-0-003706': '천공',
#  'mrc-0-001366': '신성 로마 제국',
#  'mrc-0-005387': '자동차 폐기장',
#  'mrc-0-003100': '히브리 백성',
#  'mrc-0-001021': '공산주의자',
#  'mrc-0-000898': '',
#  'mrc-1-000256': '높이뛰기',
#  'mrc-0-001382': '이탈리아',
#  'mrc-0-004932': '3년',
#  'mrc-1-000008': '히틀러의 외투',
#  'mrc-0-002723': '건강증서',
#  'mrc-0-005465': '쿠파',
#  'mrc-0-003236': '프로이센',
#  'mrc-0-003365': '트릭',
#  'mrc-0-002788': '합작 5원칙',
#  'mrc-1-000582': '화교',
#  'mrc-0-001379': '',
#  'mrc-0-001445': '16세기',
#  'mrc-0-000345': '주선회',
#  'mrc-0-002584': '정규 공간',
#  'mrc-0-004928': '미국',
#  'mrc-0-004803': '자유주의',
#  'mrc-0-004927': '대체 에너지의 개발',
#  'mrc-1-000536': '집단 극화',
#  'mrc-0-002424': '한 장군 놀이',
#  'mrc-0-000576': '소련군',
#  'mrc-0-002786': '1965',
#  'mrc-0-000205': 'William',
#  'mrc-0-002518': '이들 세대',
#  'mrc-0-005293': '링컨빌역',
#  'mrc-1-001027': '광주지방검찰청 순천지청',
#  'mrc-0-001105': '사르트르',
#  'mrc-0-000122': '종신형',
#  'mrc-0-000712': '포토맥군',
#  'mrc-0-001896': '스페셜라이즈드의 P 시리즈',
#  'mrc-0-003227': '대구',
#  'mrc-0-002215': '',
#  'mrc-0-002601': '네덜란드의 1, 2도시',
#  'mrc-0-004910': '뉴올리언스',
#  'mrc-0-002166': '하루',
#  'mrc-0-003503': '긴급 구호 건설 법령',
#  'mrc-0-001845': '루카',
#  'mrc-0-001887': '8세기',
#  'mrc-0-000316': '후장식 대포',
#  'mrc-0-003027': '막센티우스',
#  'mrc-0-005283': '시뮬레이션',
#  'mrc-1-001543': '연합군',
#  'mrc-0-002338': '루피',
#  'mrc-0-002231': '바이스',
#  'mrc-0-002983': '식품 공장',
#  'mrc-0-004017': '방수구(放水口) 부족',
#  'mrc-0-001220': '4점',
#  'mrc-0-002746': '아칸바로',
#  'mrc-0-002285': '열적작용',
#  'mrc-0-001844': '키릴 문자',
#  'mrc-1-001797': '청주',
#  'mrc-0-002028': '리을설(李乙雪, 1921-2015)',
#  'mrc-0-003031': '당 태종',
#  'mrc-1-001020': '영국',
#  'mrc-0-001574': '비토 마캔토니오',
#  'mrc-1-000155': '1996년 6월 24일',
#  'mrc-1-000801': '손가락',
#  'mrc-0-003959': '페리클레스',
#  'mrc-1-000235': "'농지",
#  'mrc-0-002716': '',
#  'mrc-0-000014': '유대인',
#  'mrc-0-000246': '톰 디마르코',
#  'mrc-0-003961': '마에노 료타쿠',
#  'mrc-0-001030': '1985년',
#  'mrc-1-001600': '플랑베르',
#  'mrc-1-001721': '이영근',
#  'mrc-1-000727': '두 가지',
#  'mrc-0-004738': '헌법',
#  'mrc-1-001584': '글래스고 대학교',
#  'mrc-1-000387': '정부',
#  'mrc-1-001370': '국제법',
#  'mrc-1-000621': '간석기(마제석기)',
#  'mrc-0-001557': '아테네',
#  'mrc-0-000850': '문장원',
#  'mrc-0-001149': '',
#  'mrc-0-000288': '《작가의 일기》',
#  'mrc-1-001690': '국립중앙박물관',
#  'mrc-1-001603': '법관 출신 인사',
#  'mrc-0-004363': '로마',
#  'mrc-0-000177': '8명',
#  'mrc-0-002514': 'API',
#  'mrc-0-001487': '정글',
#  'mrc-0-001961': '푄',
#  'mrc-0-001938': '코네티컷 소년원',
#  'mrc-1-001692': '15개',
#  'mrc-0-003356': '언더우드(Underwood)박사',
#  'mrc-0-000574': '1954년',
#  'mrc-0-004196': '요로감염증',
#  'mrc-1-001541': '유대교',
#  'mrc-1-000550': '마리아의 다섯 가지 기쁨',
#  'mrc-1-000769': '북한군',
#  'mrc-0-003442': '악',
#  'mrc-0-000114': '코드',
#  'mrc-0-002868': '1875년',
#  'mrc-0-002997': '1954년',
#  'mrc-0-002848': '잭',
#  'mrc-1-000889': '667년',
#  'mrc-1-000267': '2층',
#  'mrc-0-002654': '유튜브',
#  'mrc-0-001363': 'NASA',
#  'mrc-0-002282': '마리 알렌',
#  'mrc-1-001592': '매일 저녁',
#  'mrc-1-000013': '요새',
#  'mrc-0-003170': '1994년',
#  'mrc-0-002758': '노르웨이',
#  'mrc-1-001310': '안티트롬빈',
#  'mrc-1-001545': '차가운 점액',
#  'mrc-1-001727': '수영공원',
#  'mrc-0-004755': '옐로우스톤 공원',
#  'mrc-1-001035': '농장',
#  'mrc-0-000687': '',
#  'mrc-0-003514': '인민의용군',
#  'mrc-0-004484': '전라남도 지역',
#  'mrc-0-004310': '일본',
#  'mrc-0-002525': '',
#  'mrc-0-004855': '일본',
#  'mrc-0-001847': '광대',
#  'mrc-0-003215': '1773년',
#  'mrc-0-000328': '사실주의',
#  'mrc-0-002947': '르네상스 양식',
#  'mrc-0-001757': '1집',
#  'mrc-0-001778': '1181년',
#  'mrc-0-002720': '하후상',
#  'mrc-0-003413': '스톤페리어',
#  'mrc-0-004594': '',
#  'mrc-0-001133': '언카스(또는 다운카스, Uncas)',
#  'mrc-1-000320': '1번 ~ 9번',
#  'mrc-0-003669': '법무성이',
#  'mrc-1-001443': '일리노이주',
#  'mrc-0-004862': '정통 칼리파(Al-Khalifah Ar-Rashid)',
#  'mrc-1-001549': '경추',
#  'mrc-0-003821': '알렉산드리아 근교의 마렝고에서',
#  'mrc-0-002832': '브라질',
#  'mrc-1-000691': '말',
#  'mrc-0-001607': '스렝도',
#  'mrc-0-003454': '1989년',
#  'mrc-0-000206': '상원',
#  'mrc-0-001179': '소프트웨어 엔지니어링',
#  'mrc-0-003043': '경시청 수사1과',
#  'mrc-0-004648': '장기간',
#  'mrc-0-003434': '재산권 박탈',
#  'mrc-0-002074': '10일',
#  'mrc-1-000580': '킹',
#  'mrc-0-005097': '트리노반트족',
#  'mrc-0-001324': '서울특별시',
#  'mrc-0-002816': '천박',
#  'mrc-0-000895': '줄기군 절지동물',
#  'mrc-0-002127': '4막 3장이',
#  'mrc-0-002436': '오스트리아-헝가리 제국 시대',
#  'mrc-0-002265': '1935년',
#  'mrc-0-003068': '시구르드',
#  'mrc-0-001438': '고달',
#  'mrc-0-001072': '새누리당',
#  'mrc-0-002927': '12척',
#  'mrc-0-000028': '슈퍼캅인',
#  'mrc-1-000292': '오티스 소프',
#  'mrc-0-001415': '절도사',
#  'mrc-0-000499': '극단적인 자전축 경사',
#  'mrc-1-000650': '광물',
#  'mrc-0-000780': '밑',
#  'mrc-1-001635': '배우자',
#  'mrc-0-003105': '폭동이 발생하면 그것을 진압한다는 명목',
#  'mrc-0-001689': '1671년',
#  'mrc-0-002170': '《소우기》(小右記)',
#  'mrc-0-000964': '하리수',
#  'mrc-0-002414': '머리와 손목',
#  'mrc-0-000668': '론케발레스 언덕',
#  'mrc-0-003544': '',
#  'mrc-0-002033': '급진',
#  'mrc-1-000189': '공수부대',
#  'mrc-0-003180': '한스 칼 폰 빈터펠트 장군',
#  'mrc-1-001214': '워터세븐',
#  'mrc-0-004245': '내무대신',
#  'mrc-1-001689': '스승',
#  'mrc-0-002777': '삼흥',
#  'mrc-1-001394': '',
#  'mrc-1-001716': '1945년',
#  'mrc-0-002979': '5칸',
#  'mrc-0-002493': '미국',
#  'mrc-0-002092': '「소방공무원법」',
#  'mrc-0-002536': '리히노브스키',
#  'mrc-0-002219': '위험한 물질',
#  'mrc-1-001196': '다케다 요헤이',
#  'mrc-0-004690': '리 컬른',
#  'mrc-0-002045': '송병하',
#  'mrc-0-002879': '이스라엘',
#  'mrc-0-003617': '트로츠키',
#  'mrc-0-002618': '',
#  'mrc-0-001614': '조선 후기',
#  'mrc-0-004674': '테코아쿠',
#  'mrc-0-000393': '2005년',
#  'mrc-0-003645': '<핼로 돌리>',
#  'mrc-0-001272': '고현',
#  'mrc-0-000740': '학습자가 정보 통달에 이를 때까지',
#  'mrc-0-003639': '로지반',
#  'mrc-0-003904': '1913년',
#  'mrc-0-005094': '여성 금주 동맹',
#  'mrc-0-005209': '일본',
#  'mrc-0-003716': '오스트리아',
#  'mrc-0-004081': '',
#  'mrc-0-001180': '1807년',
#  'mrc-0-001046': '프랭클린 D. 루스벨트',
#  'mrc-0-001863': '베다의 권위를 인정하는 가의 여부',
#  'mrc-0-003926': '',
#  'mrc-0-000500': '2008년',
#  'mrc-0-001654': '붉은 구슬',
#  'mrc-0-001123': '빈곤수출',
#  'mrc-1-000056': '패트릭 자라',
#  'mrc-0-000852': '가족의 화합',
#  'mrc-0-003331': '200만 달러',
#  'mrc-1-001071': '아서',
#  'mrc-0-001192': '헌재',
#  'mrc-0-005108': '에로스',
#  'mrc-0-004329': '황소',
#  'mrc-1-001425': '260억 개',
#  'mrc-1-001769': '헝가리',
#  'mrc-0-002916': '퀸투스 루타티우스 카툴루스',
#  'mrc-0-000435': '',
#  'mrc-1-001269': '패닌',
#  'mrc-0-000459': '내각회의',
#  'mrc-1-000713': '드주드주아나의 동굴',
#  'mrc-1-000218': '《나뭇잎의 집》',
#  'mrc-0-004970': '1~2마리',
#  'mrc-1-000690': '아들',
#  'mrc-0-003499': '초음파 가습기',
#  'mrc-1-000181': '강세황',
#  'mrc-0-003996': '사쿠라',
#  'mrc-0-004708': '위장',
#  'mrc-0-005410': '10월 21일',
#  'mrc-0-004579': '취리히',
#  'mrc-0-001793': '플라티니',
#  'mrc-0-000255': '인사관리에 대한 통제권',
#  'mrc-0-001705': '슈베르트',
#  'mrc-0-001539': '목포',
#  'mrc-1-001624': '',
#  'mrc-1-000694': '남평',
#  'mrc-0-001425': '중심지 이동설',
#  'mrc-1-001516': '가속화 분류기',
#  'mrc-1-000954': '1989년',
#  'mrc-0-005166': '괜찮',
#  'mrc-0-000096': '2009년 8월',
#  'mrc-0-003596': '부당한 일요등교 지시',
#  'mrc-0-002651': '영국',
#  'mrc-0-001370': 'M2G',
#  'mrc-0-002766': '1969년',
#  'mrc-0-000150': '헝가리',
#  'mrc-0-000760': '가입이 차단',
#  'mrc-1-000870': "'영혼의 의식'",
#  'mrc-1-001011': '뷔르츠부르크 대학교',
#  'mrc-1-000112': '순치제',
#  'mrc-0-004510': '인체의 치수(인체측정학의 측정 기준)',
#  'mrc-1-001436': '앙리 블랑슈',
#  'mrc-0-002482': '근원 마그마가 형성되는 기작이 다르기 때문',
#  'mrc-0-000527': '',
#  'mrc-0-004840': '홈즈',
#  'mrc-0-001931': '독일군',
#  'mrc-0-004832': '세벌식 자판',
#  'mrc-1-001729': '수리물리학',
#  'mrc-0-000866': '1945년',
#  'mrc-1-000278': '소장',
#  'mrc-0-000723': '빛',
#  'mrc-0-000942': '성우',
#  'mrc-0-004280': '사츠키',
#  'mrc-1-000518': '아드레날린',
#  'mrc-0-004371': '모팻',
#  'mrc-1-001582': '1934년',
#  'mrc-0-002164': "인간의 최고 유산(Man's Supreme Inheritance)",
#  'mrc-0-001076': '베다는',
#  'mrc-0-003962': '뉴질랜드',
#  'mrc-1-000094': '구와바라 다케오(桑原武夫, 교토대 명예교수)',
#  'mrc-1-001301': '캘빈 쿨리지',
#  'mrc-0-002763': '강릉',
#  'mrc-0-001429': '오스만',
#  'mrc-1-000651': '',
#  'mrc-0-004649': '경찰',
#  'mrc-0-004438': '학문적 역량',
#  'mrc-0-005422': "'어떤 끔찍한 실험'",
#  'mrc-0-000845': '오삼계',
#  'mrc-0-002188': '아스파르트산',
#  'mrc-0-003648': '상대적 손실 가치',
#  'mrc-0-003069': '블루 라인',
#  'mrc-0-004759': '하이브리드 잉크 배합물',
#  'mrc-1-000412': '미하일린',
#  'mrc-0-001078': '1946년',
#  'mrc-0-000394': '김정은',
#  'mrc-0-002289': '남해안',
#  'mrc-0-000734': '외국인',
#  'mrc-1-000770': '중동',
#  'mrc-0-004187': '김성원',
#  'mrc-1-001554': '야기옐론 대학',
#  'mrc-0-000062': '부숴졌지만',
#  'mrc-0-003460': '레기온',
#  'mrc-0-003038': '에우리아의 요한',
#  'mrc-0-001682': '사형',
#  'mrc-0-001457': '일본',
#  'mrc-1-000143': '잠업강습소',
#  'mrc-0-003755': '무신',
#  'mrc-0-001393': '마이클 뉴먼',
#  'mrc-0-001790': '스카버러 타운 센터',
#  'mrc-0-003418': '의사결정권자',
#  'mrc-0-002696': '1984년',
#  'mrc-0-004465': '세라 페일린',
#  'mrc-0-002840': '화이트워터 사건',
#  'mrc-1-000972': '폭탄',
#  'mrc-1-000227': '동탁의 군대',
#  'mrc-0-002155': '서울',
#  'mrc-0-000564': '1970년',
#  'mrc-0-001660': '3미터',
#  'mrc-0-004323': '연극배우',
#  'mrc-0-000664': '벤자민 바커',
#  'mrc-0-000913': '탈당',
#  'mrc-0-004373': '5월 29일',
#  'mrc-0-004392': '뇌',
#  'mrc-1-001229': 'OekakiBBS',
#  'mrc-0-005342': '소루트비히',
#  'mrc-0-000030': '향교',
#  'mrc-0-002098': '교황 율리오 2세',
#  'mrc-0-000162': '튀레쇠 FF',
#  'mrc-0-000784': '프랑스',
#  'mrc-0-004040': '안티오쿠스',
#  'mrc-1-001277': '좀비',
#  'mrc-0-000434': '',
#  'mrc-0-002096': '1947년',
#  'mrc-0-001878': '',
#  'mrc-0-000211': '실루엣',
#  'mrc-0-004085': 'R. H. 앨런',
#  'mrc-0-004909': '모술',
#  'mrc-0-003441': '1988',
#  'mrc-0-003807': '키홀더',
#  'mrc-0-001026': '86 편의',
#  'mrc-1-000524': '밀로셰비치',
#  'mrc-0-001864': '보리스 타디치',
#  'mrc-0-004467': '1993년',
#  'mrc-0-002636': '1977년',
#  'mrc-0-004710': '공훈의 보상',
#  'mrc-0-002581': '중앙위원회',
#  'mrc-0-005012': '"이탈리아 요리"',
#  'mrc-0-003040': '일본',
#  'mrc-0-003558': '연방 정부',
#  'mrc-1-001670': '현무암 화방벽',
#  'mrc-0-004531': '판옥선',
#  'mrc-0-003835': '피렌체',
#  'mrc-0-002683': '1726년',
#  'mrc-0-003770': '간헐천',
#  'mrc-0-003053': '조선혁명간부학교',
#  'mrc-1-001426': '대법원',
#  'mrc-0-002782': '임금',
#  'mrc-0-002245': '레드훅 스튜디오',
#  'mrc-0-004111': '1924년',
#  'mrc-1-001775': '시코쿠 섬',
#  'mrc-0-002130': '러시아',
#  'mrc-1-001559': '소방방재센터',
#  'mrc-1-000627': '1967년 11월 15일',
#  'mrc-0-004672': '존 벨링햄',
#  'mrc-1-001051': '',
#  'mrc-1-001316': '동국전자공과대학',
#  'mrc-1-000977': '풍선',
#  'mrc-1-000788': '영국',
#  'mrc-0-002530': '안티오코스 3세',
#  'mrc-0-002481': '엘프',
#  'mrc-0-000283': '비올라',
#  'mrc-0-003501': '백병계열군',
#  'mrc-0-003500': '급소',
#  'mrc-0-004308': '356',
#  'mrc-1-000841': '민영달',
#  'mrc-1-001669': '부근 대밭골',
#  'mrc-0-005486': '조조',
#  'mrc-0-004372': '대구',
#  'mrc-0-000944': '용수',
#  'mrc-0-004410': '공산주의자',
#  'mrc-0-001659': 'ㅋ',
#  'mrc-0-002991': '리 셔츠',
#  'mrc-0-001251': '공화당원 투표인들 만을 화나',
#  'mrc-0-003528': '원제',
#  'mrc-0-002877': '해리',
#  'mrc-1-000177': '제8조',
#  'mrc-0-005447': '석재',
#  'mrc-1-001517': '강원도관찰사',
#  'mrc-0-003711': '성철(이영주)',
#  'mrc-0-004394': '아리스토텔레스',
#  'mrc-0-004335': '블룸버그',
#  'mrc-0-000651': '1967년',
#  'mrc-0-002989': '재단 X',
#  'mrc-0-001804': '자유당',
#  'mrc-0-003411': '서스펜디드 게임',
#  'mrc-0-003436': '소드 해변',
#  'mrc-0-002605': '수수께끼의 콘드률'}
